# %%
import pandas as pd

# %%
df = pd.read_csv("../data/final_df.csv")
df = df.drop_duplicates(subset=["artist"]).reset_index(drop=True)

# %%
df
# Out:
#                 track_id                        name                artist  \
# 0     TRHNGJL128F9310B69    East St. Louis Toodle-Oo            Steely Dan
# 1     TRRXFHO128EF3550BC               Fast as I Can   Stone Temple Pilots
# 2     TRXVLQC128F9324EFB                     Ray Gun  The Bird and the Bee
# 3     TRHSGXW12903CE895F           Drunken Lullabies        Flogging Molly
# 4     TRLHRQJ128F424831C                       Denia             Manu Chao
# ...                  ...                         ...                   ...
# 5959  TRUWVHD128F422FC2B                     Imagina           Genitallica
# 5960  TRIOFUF128F427E139                    Fired Up                  Hush
# 5961  TRLOKQA128F42352CB                   Strollin'               Matty G
# 5962  TRXCJNL128F4292F60  Baubles, Bangles and Beads          Eliane Elias
# 5963  TRINATQ128F93019DE                 Hard To Get     Florence Rawlings
#
#                                     spotify_preview_url  \
# ...

# %%
df.iloc[0:1500]
# Out:
#                 track_id                      name                artist  \
# 0     TRHNGJL128F9310B69  East St. Louis Toodle-Oo            Steely Dan
# 1     TRRXFHO128EF3550BC             Fast as I Can   Stone Temple Pilots
# 2     TRXVLQC128F9324EFB                   Ray Gun  The Bird and the Bee
# 3     TRHSGXW12903CE895F         Drunken Lullabies        Flogging Molly
# 4     TRLHRQJ128F424831C                     Denia             Manu Chao
# ...                  ...                       ...                   ...
# 1495  TRONGJW12903CE7FC2     I'll Read You a Story               Colleen
# 1496  TRNZEEL128EF33FE47         The Greater Times           Electrelane
# 1497  TRRHBZV128F933DD94         Then He Kissed Me          The Crystals
# 1498  TRXCDWV12903D06EC6           Bohemian Forest      Pantha du Prince
# 1499  TRDBIXL128E0782FCA             The Passenger              Iggy Pop
#
#                                     spotify_preview_url  \
# ...
